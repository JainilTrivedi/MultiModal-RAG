# %%
from unittest.mock import patch
import unittest
from DPS_RAG import chat_history, main

class TestMainFunction(unittest.TestCase):
    @patch('builtins.input', side_effect=["no", "How do we categorize tasks into groups based on a parameter denoted as τ."])
    def test_math_expression(self):
        main(chat_history)
        print("Test Math Expression - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

    @patch('builtins.input', side_effect=["no", "Describe Figure 4."])
    def test_image_related_query(self):
        main(chat_history)
        print("Test Image-Related Query - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

    @patch('builtins.input', side_effect=["no", "Elaborate table 3 from the paper."])
    def test_table_query(self):
        main(chat_history)
        print("Test Table Query - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

    @patch('builtins.input', side_effect=["yes", "Describe the image based on the context."])
    def test_image_query(self):
        main(chat_history)
        print("Test Image Query - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

    @patch('builtins.input', side_effect=["no", "Explain T1 Fact Retrieval."])
    def test_fact_retrieval(self):
        main(chat_history)
        print("Test Fact Retrieval - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

    @patch('builtins.input', side_effect=["no", "Define Single and Multi Index models."])
    def test_define_models(self):
        main(chat_history)
        print("Test Define Models - Chat History:", chat_history)
        self.assertGreater(len(chat_history), 0)
        self.assertIsNotNone(chat_history[0][1])

if __name__ == "__main__":
    unittest.main()
